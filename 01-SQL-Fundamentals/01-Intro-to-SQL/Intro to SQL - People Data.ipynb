# %%
# Full dataset has 8397 rows

import pandas as pd

url = 'https://raw.githubusercontent.com/datacamp/courses-introduction-to-sql/master/data/films/people.csv'

df = pd.read_csv(url, index_col=0)
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#                                   name   birthdate   deathdate
# id
# 1                              50 Cent  1975-07-06         NaN
# 2                   A. Michael Baldwin  1963-04-04         NaN
# 3                        A. Raven Cruz         NaN         NaN
# 4                         A.J. Buckley  1978-02-09         NaN
# 5                         A.J. DeLucia         NaN         NaN
# 6                          A.J. Langer  1974-05-22         NaN
# 7                              Aaliyah  1979-01-16  2001-08-25
# 8                        Aaron Ashmore  1979-10-07         NaN
# 9                           Aaron Hann         NaN         NaN
# 10                          Aaron Hill  1983-04-23         NaN
# 11                        Aaron Hughes         NaN         NaN
# 12                          Aaron Kwok  1965-10-26         NaN
# 13                     Aaron Schneider         NaN         NaN
# 14                       Aaron Seltzer  1974-01-12         NaN
# ...
