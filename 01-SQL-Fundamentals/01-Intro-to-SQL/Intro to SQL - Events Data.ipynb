# %%
# Full dataset has 645 rows

import pandas as pd

url = 'https://raw.githubusercontent.com/datacamp/courses-introduction-to-sql/master/data/olympics/events.csv'

df = pd.read_csv(url, index_col=0)

with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df)
# Out:
#                                                   name              sport  \
# id
# 1                                - 47.63kg (flyweight)             Boxing
# 2                           - 47.6kg (light-flyweight)          Wrestling
# 3                                              - 48 kg               Judo
# 4                                               - 48kg          Wrestling
# 5                           - 48kg (extra-lightweight)               Judo
# 6                             - 48kg (light-flyweight)             Boxing
# 7                             - 48kg (light-flyweight)          Wrestling
# 8                             - 48kg (light-flyweight)          Wrestling
# 9                                              - 49 kg          Taekwondo
# 10                                - 50.8kg (flyweight)             Boxing
# 11                                  - 51kg (flyweight)             Boxing
# 12                            - 52.62kg (bantamweight)             Boxing
# ...
